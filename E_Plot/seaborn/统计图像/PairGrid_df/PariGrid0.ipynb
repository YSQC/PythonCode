# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Draw a scatterplot for each pairwise relationship:
g = sns.PairGrid(iris)
g = g.map(plt.scatter)
print(g.fig, len(g.fig.get_axes()), end='\n\n')
for i in g.fig.get_axes():
    print('title:', i.get_title())
    print('xlabel:', i.get_xlabel())
    print('ylabel:', i.get_ylabel())
    print('xlim:', i.get_xlim())
    print('ylim:', i.get_ylim())
    print('xticks:', i.get_xticks())
    print('xticklabels:', i.get_xticklabels(), end='\n\n')
# Out:
# Figure(720x720) 16
#
# title:
# xlabel:
# ylabel: sepal_length
# xlim: (4.020360758961666, 8.179639241038332)
# ylim: (4.028891069832203, 8.1711089301678)
# xticks: [ 4.  6.  8. 10.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (1.8135729607777922, 4.586427039222206)
# ylim: (4.028891069832203, 8.1711089301678)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (0.5417040388140859, 7.358295961185902)
# ylim: (4.028891069832203, 8.1711089301678)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.0864270392222049, 2.6864270392222083)
# ylim: (4.028891069832203, 8.1711089301678)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel: sepal_width
# xlim: (4.020360758961666, 8.179639241038332)
# ylim: (1.8192600889290769, 4.580739911070924)
# xticks: [ 4.  6.  8. 10.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (1.8135729607777922, 4.586427039222206)
# ylim: (1.8192600889290769, 4.580739911070924)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (0.5417040388140859, 7.358295961185902)
# ylim: (1.8192600889290769, 4.580739911070924)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.0864270392222049, 2.6864270392222083)
# ylim: (1.8192600889290769, 4.580739911070924)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel: petal_length
# xlim: (4.020360758961666, 8.179639241038332)
# ylim: (0.5556837832298589, 7.344316216770134)
# xticks: [ 4.  6.  8. 10.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (1.8135729607777922, 4.586427039222206)
# ylim: (0.5556837832298589, 7.344316216770134)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (0.5417040388140859, 7.358295961185902)
# ylim: (0.5556837832298589, 7.344316216770134)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel:
# ylabel:
# xlim: (-0.0864270392222049, 2.6864270392222083)
# ylim: (0.5556837832298589, 7.344316216770134)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: <a list of 0 Text xticklabel objects>
#
# title:
# xlabel: sepal_length
# ylabel: petal_width
# xlim: (4.020360758961666, 8.179639241038332)
# ylim: (-0.08073991107092438, 2.680739911070924)
# xticks: [ 4.  6.  8. 10.]
# xticklabels: <a list of 4 Text xticklabel objects>
#
# title:
# xlabel: sepal_width
# ylabel:
# xlim: (1.8135729607777922, 4.586427039222206)
# ylim: (-0.08073991107092438, 2.680739911070924)
# xticks: [1. 2. 3. 4. 5.]
# xticklabels: <a list of 5 Text xticklabel objects>
#
# title:
# xlabel: petal_length
# ylabel:
# xlim: (0.5417040388140859, 7.358295961185902)
# ylim: (-0.08073991107092438, 2.680739911070924)
# xticks: [0. 2. 4. 6. 8.]
# xticklabels: <a list of 5 Text xticklabel objects>
#
# title:
# xlabel: petal_width
# ylabel:
# xlim: (-0.0864270392222049, 2.6864270392222083)
# ylim: (-0.08073991107092438, 2.680739911070924)
# xticks: [-1.  0.  1.  2.  3.]
# xticklabels: <a list of 5 Text xticklabel objects>

# %%
# Show a univariate distribution on the diagonal:
g = sns.PairGrid(iris)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)

# %%
# Color the points using a categorical variable:
g = sns.PairGrid(iris, hue="species")
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
#Use a different style to show multiple histograms:
g = sns.PairGrid(iris, hue="species")
g = g.map_diag(plt.hist, histtype="step", linewidth=3)
g = g.map_offdiag(plt.scatter)
g = g.add_legend()

# %%
# Plot a subset of variables
g = sns.PairGrid(iris, vars=["sepal_length", "sepal_width"])
g = g.map(plt.scatter)

# %%
# Pass additional keyword arguments to the functions
g = sns.PairGrid(iris)
g = g.map_diag(plt.hist, edgecolor="w")
g = g.map_offdiag(plt.scatter, edgecolor="w", s=40)

# %%
# Use different variables for the rows and columns:
g = sns.PairGrid(iris,
                  x_vars=["sepal_length", "sepal_width"],
                  y_vars=["petal_length", "petal_width"])
g = g.map(plt.scatter)

# %%
# Use different functions on the upper and lower triangles:
g = sns.PairGrid(iris)
import  numpy as np
g = g.map_upper(plt.scatter, color=plt.cm.cool(np.linspace(0, 1, len(iris['sepal_length']))))
g = g.map_lower(sns.kdeplot, cmap="Blues_d")
g = g.map_diag(sns.kdeplot, lw=3, legend=False)
# Out:
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)
# D:\Program\anaconda3\lib\site-packages\matplotlib\contour.py:960: UserWarning: The following kwargs were not used by contour: 'label', 'color'
#   s)

# %%
# Use different colors and markers for each categorical level:
g = sns.PairGrid(iris, hue="species", palette="Set2",
                  hue_kws={"marker": ["o", "s", "D"]}, despine=True,
                 size=3, aspect=1)
g = g.map(plt.scatter, linewidths=1, edgecolor="w", s=40)
g = g.add_legend()
